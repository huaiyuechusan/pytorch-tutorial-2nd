# %%
import time
import torch
import numpy as np
from torchvision import models

# %%
mode_list = "default reduce-overhead max-autotune".split()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 实验一：sin函数

# %%
def sin_func(x):
    return torch.sin(x) + torch.cos(x)

run_times = 100000
i_data = torch.tensor(1).to(device)
for mode in mode_list:
    torch.cuda.synchronize()
    time_0 = time.time()
    module_compiled = torch.compile(sin_func, mode=mode)
    torch.cuda.synchronize()
    time_1 = time.time()
    
    # warmup
    sin_func(i_data)
    module_compiled(i_data)
    
    torch.cuda.synchronize()
    time_2 = time.time()
    for i in range(run_times):
        sin_func(i_data)
        
    torch.cuda.synchronize()
    time_3 = time.time()
    for i in range(run_times):
        module_compiled(i_data)
    torch.cuda.synchronize()
    time_4 = time.time()
    
    compile_time = time_1 - time_0
    pre_time = time_3 - time_2
    post_time = time_4 - time_3
    speedup_ratio = (pre_time - post_time)/pre_time
    
    print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT sin_func C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8016\3035411914.py line 1
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 10:28:53.301000 10632 torch\_dynamo\convert_frame.py:1009]
# mode: default, 编译耗时:0.00，编译前运行耗时:2.91, 编译后运行耗时:3.75，速度提升比例:-28.79%
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:2.87, 编译后运行耗时:3.65，速度提升比例:-26.91%
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:2.89, 编译后运行耗时:3.71，速度提升比例:-28.32%

# %% [markdown]
# # 实验二：resnet18

# %%
resnet18 = models.resnet18().to(device)
resnet18.eval()
fake_img = torch.randn(16, 3, 224, 224).to(device)

# %%
run_times = 100
with torch.no_grad():
    for mode in mode_list:
        torch.cuda.synchronize()
        time_0 = time.time()
        module_compiled = torch.compile(resnet18, mode=mode)
        torch.cuda.synchronize()
        time_1 = time.time()
        
        # warmup 非常关键！
        resnet18(fake_img)
        module_compiled(fake_img)
        
        #
        torch.cuda.synchronize()
        time_2 = time.time()
        for i in range(run_times):
            resnet18(fake_img)
        
        torch.cuda.synchronize()
        time_3 = time.time()
        for i in range(run_times):
            module_compiled(fake_img)
        
        torch.cuda.synchronize()
        time_4 = time.time()

        compile_time = time_1 - time_0
        pre_time = time_3 - time_2
        post_time = time_4 - time_3
        speedup_ratio = (pre_time - post_time)/pre_time

        print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT forward G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torchvision\models\resnet.py line 284
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:48:56.029000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT _forward_impl G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torchvision\models\resnet.py line 266
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.492000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# ...
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:48:58.754000 10632 torch\_dynamo\convert_frame.py:1009]
# mode: default, 编译耗时:0.00，编译前运行耗时:2.81, 编译后运行耗时:2.80，速度提升比例:0.27%
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:2.78, 编译后运行耗时:2.81，速度提升比例:-0.95%
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:2.86, 编译后运行耗时:2.79，速度提升比例:2.29%

# %% [markdown]
# # 实验三：BERT

# %%
from transformers import BertModel, BertTokenizer
import time

bert = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# 准备一批输入数据
input_text = "Here is some text to encode"
inputs = tokenizer(input_text, return_tensors='pt', padding=True, truncation=True)
inputs = {k: v.to(device) for k, v in inputs.items()}
bert.to(device)
bert.eval()

run_times = 100
with torch.no_grad():
    for mode in mode_list:
        
        # 编译
        torch.cuda.synchronize()
        time_0 = time.time()
        bert_compiled = torch.compile(bert, mode=mode)
        torch.cuda.synchronize()
        time_1 = time.time()
        
        # warmup 非常关键！
        bert(**inputs)
        bert_compiled(**inputs)

        torch.cuda.synchronize()
        time_2= time.time()
        for _ in range(run_times): 
            _ = bert(**inputs)

        torch.cuda.synchronize()
        time_3= time.time()
        for _ in range(run_times):
            _ = bert_compiled(**inputs)
        
        torch.cuda.synchronize()
        time_4= time.time()
        
        compile_time = time_1 - time_0
        pre_time = time_3 - time_2
        post_time = time_4 - time_3
        speedup_ratio = (pre_time - post_time)/pre_time
        
        
        print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\transformers\models\bert\modeling_bert.py:435: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT forward G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\transformers\models\bert\modeling_bert.py line 996
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1123, in compile_subgraph
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1123, in compile_subgraph
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:58:13.110000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT forward G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\transformers\models\bert\modeling_bert.py line 180
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:58:13.306000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1098, in compile_subgraph
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1678, in compile_to_module
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                                                              ^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1634, in codegen
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.scheduler = Scheduler(self.buffers)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in __init__
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1364, in <listcomp>
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 1462, in create_scheduler_node
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     return SchedulerNode(self, node)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 731, in __init__
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self._compute_attrs()
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 742, in _compute_attrs
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2663, in get_backend
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     self.backends[device] = self.create_backend(device)
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\scheduler.py", line 2655, in create_backend
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Cannot find a working triton installation. More information on installing Triton can be found at https://github.com/openai/triton
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 09:58:22.295000 10632 torch\_dynamo\convert_frame.py:1009]
# mode: default, 编译耗时:0.00，编译前运行耗时:0.86, 编译后运行耗时:0.92，速度提升比例:-7.90%
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:0.78, 编译后运行耗时:0.91，速度提升比例:-16.75%
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:0.78, 编译后运行耗时:0.90，速度提升比例:-15.76%

# %% [markdown]
# # 实验四 numpy

# %%
run_times = 100

def numpy_fn2(X: np.ndarray, Y: np.ndarray) -> np.ndarray:
    return np.sum(X[:, :, None] * Y[:, None, :], axis=(-2, -1))

def numpy_fn(X: np.ndarray, Y: np.ndarray) -> np.ndarray:
    # Step 1: Normalize the input arrays to have zero mean and unit variance
    X_mean, X_std = X.mean(axis=0), X.std(axis=0)
    Y_mean, Y_std = Y.mean(axis=0), Y.std(axis=0)
    
    # Avoid division by zero in case of zero standard deviation
    X_std[X_std == 0] = 1
    Y_std[Y_std == 0] = 1
    
    X_normalized = (X - X_mean) / X_std
    Y_normalized = (Y - Y_mean) / Y_std
    
    # Step 2: Perform the tensor product followed by sum over last two dimensions
    intermediate_result = np.sum(X_normalized[:, :, None] * Y_normalized[:, None, :], axis=(-2, -1))
    
    # Step 3: Apply thresholding to clip values outside of [-1, 1]
    intermediate_result = np.clip(intermediate_result, -1, 1)
    
    # Step 4: Apply exponential function for non-linearity
    result = np.exp(intermediate_result)
    
    # Step 5: Add a small regularization term to avoid overfitting
    regularization_term = 0.001 * np.sum(X_normalized ** 2 + Y_normalized ** 2, axis=1)
    result += regularization_term
    
    return result

x = np.random.randn(1024, 640)
y = np.random.randn(1024, 640)

for mode in mode_list:
    torch.cuda.synchronize()
    time_0 = time.time()
    numpy_fn_compiled = torch.compile(numpy_fn, mode=mode)
    torch.cuda.synchronize()
    time_1 = time.time()

    # warmup 非常关键！
    numpy_fn(x, y)
    numpy_fn_compiled(x, y)

    #
    torch.cuda.synchronize()
    time_2 = time.time()
    for i in range(run_times):
        numpy_fn(x, y)

    torch.cuda.synchronize()
    time_3 = time.time()
    for i in range(run_times):
        numpy_fn_compiled(x, y)

    torch.cuda.synchronize()
    time_4 = time.time()

    compile_time = time_1 - time_0
    pre_time = time_3 - time_2
    post_time = time_4 - time_3
    speedup_ratio = (pre_time - post_time)/pre_time

    print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] WON'T CONVERT numpy_fn C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8016\3604335613.py line 6
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] due to:
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1123, in compile_subgraph
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1699, in compile_to_module
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     mod = PyCodeCache.load_by_key_path(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\codecache.py", line 3062, in load_by_key_path
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     mod = _reload_python_module(key, path)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\runtime\compile_tasks.py", line 39, in _reload_python_module
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Failed to import C:\Users\Lenovo\AppData\Local\Temp\torchinductor_Lenovo\2q\c2qf5y7melus7i4jicj675wxfids6cp3iblrudkjmsp4o6udutzj.py
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 13-14: truncated \UXXXXXXXX escape (c2qf5y7melus7i4jicj675wxfids6cp3iblrudkjmsp4o6udutzj.py, line 176)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] Traceback (most recent call last):
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 948, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     result = self._inner_convert(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]              ^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 472, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return _compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_utils_internal.py", line 84, in wrapper_function
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return StrobelightCompileTimeProfiler.profile_compile_time(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_strobelight\compile_time_profiler.py", line 129, in profile_compile_time
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 817, in _compile
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 636, in compile_inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     out_code = transform_code_object(code, transform)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1185, in transform_code_object
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     transformations(instructions, code_options)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 178, in _fn
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\convert_frame.py", line 582, in transform
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     tracer.run()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2451, in run
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     super().run()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 893, in run
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     while self.step():
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 805, in step
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.dispatch_table[inst.opcode](self, inst)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2642, in RETURN_VALUE
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self._return(inst)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2627, in _return
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.output.compile_subgraph(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1123, in compile_subgraph
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1318, in compile_and_call_fx_graph
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = self.call_user_compiler(gm)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1409, in call_user_compiler
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\output_graph.py", line 1390, in call_user_compiler
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_gm = compiler_fn(gm, example_inputs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\__init__.py", line 1951, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1505, in compile_fx
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return aot_autograd(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\backends\common.py", line 69, in __call__
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 954, in aot_module_simplified
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, _ = create_aot_dispatcher_function(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\aot_autograd.py", line 687, in create_aot_dispatcher_function
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn, fw_metadata = compiler_fn(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                                ^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 168, in aot_dispatch_base
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 1410, in fw_compiler_base
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return inner_compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 84, in debug_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return fn(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 527, in compile_fx_inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_graph = fx_codegen_and_compile(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\contextlib.py", line 81, in inner
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return func(*args, **kwds)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\compile_fx.py", line 831, in fx_codegen_and_compile
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     compiled_fn = graph.compile_to_fn()
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]                   ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1749, in compile_to_fn
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     return self.compile_to_module().call
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_dynamo\utils.py", line 231, in time_wrapper
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     r = func(*args, **kwargs)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]         ^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\graph.py", line 1699, in compile_to_module
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     mod = PyCodeCache.load_by_key_path(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\codecache.py", line 3062, in load_by_key_path
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     mod = _reload_python_module(key, path)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]   File "G:\Anaconda3\envs\pytorch2.4\Lib\site-packages\torch\_inductor\runtime\compile_tasks.py", line 39, in _reload_python_module
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]     raise RuntimeError(
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] RuntimeError: Failed to import C:\Users\Lenovo\AppData\Local\Temp\torchinductor_Lenovo\2q\c2qf5y7melus7i4jicj675wxfids6cp3iblrudkjmsp4o6udutzj.py
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 13-14: truncated \UXXXXXXXX escape (c2qf5y7melus7i4jicj675wxfids6cp3iblrudkjmsp4o6udutzj.py, line 176)
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0806 10:14:59.652000 10632 torch\_dynamo\convert_frame.py:1009]
# mode: default, 编译耗时:0.00，编译前运行耗时:139.91, 编译后运行耗时:140.94，速度提升比例:-0.74%
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:134.90, 编译后运行耗时:137.07，速度提升比例:-1.61%
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:136.81, 编译后运行耗时:137.11，速度提升比例:-0.22%
